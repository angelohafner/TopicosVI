# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
tLim = 2
t = np.linspace(0,tLim,11)
s = np.linspace(0,15,11)

# %%
T,S = np.meshgrid(t,s)
r = 1
dS_dt = r * S
ang = np.arctan(dS_dt)
u = sc * np.cos(ang)
v = np.sin(ang)

plt.figure(figsize=(4,5),dpi=300)
plt.quiver(T,S,u,v,label='$dy/dt$',angles='xy')
plt.xlabel('$t$ [anos]')
plt.ylabel('$y(t)$ [indivíduos]')
for P0 in range(0,6,1):
  ttt = np.linspace(0,tLim,100)
  P_sol = P0 * np.exp(r*ttt)
  plt.plot(ttt,P_sol,lw=3,label=P0)
plt.legend()
plt.ylim([0,15])
plt.grid()

# %%
15/tLim
# Out:
# 7.5
