# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Fazendo os gráficos bonitos

# %%
plt.style.use(['science','notebook','grid'])

# %% [markdown]
# # Gráficos
# ## Gráficos de Linha

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)

# %%
plt.plot(x,y)
plt.show()
