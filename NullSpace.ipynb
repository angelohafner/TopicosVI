# %%
# https://youtu.be/FgXp28Abllw
from sympy import Matrix, init_printing
init_printing()

# %%
A = Matrix([[1,2,2,2],[2,4,6,8],[3,6,8,10]])
A
# Out:
# ⎡1  2  2  2 ⎤
# ⎢           ⎥
# ⎢2  4  6  8 ⎥
# ⎢           ⎥
# ⎣3  6  8  10⎦

# %%
A.rref()
# Out:
# ⎛⎡1  2  0  -2⎤        ⎞
# ⎜⎢           ⎥        ⎟
# ⎜⎢0  0  1  2 ⎥, (0, 2)⎟
# ⎜⎢           ⎥        ⎟
# ⎝⎣0  0  0  0 ⎦        ⎠

# %%
A.nullspace()
# Out:
# ⎡⎡-2⎤  ⎡2 ⎤⎤
# ⎢⎢  ⎥  ⎢  ⎥⎥
# ⎢⎢1 ⎥  ⎢0 ⎥⎥
# ⎢⎢  ⎥, ⎢  ⎥⎥
# ⎢⎢0 ⎥  ⎢-2⎥⎥
# ⎢⎢  ⎥  ⎢  ⎥⎥
# ⎣⎣0 ⎦  ⎣1 ⎦⎦
