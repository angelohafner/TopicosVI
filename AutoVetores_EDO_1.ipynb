# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
M = sp.Matrix([[0, 1],[-1, -sp.Rational(5,2)]])
M
# Out:
# Matrix([
# [ 0,    1],
# [-1, -5/2]])

# %%
P,D = M.diagonalize()
sp.latex(P)
# Out:
# '\\left[\\begin{matrix}-1 & -2\\\\2 & 1\\end{matrix}\\right]'

# %%
D
# Out:
# Matrix([
# [-2,    0],
# [ 0, -1/2]])

# %%
m = np.matrix([[0, 1],[-1, -5/2]])
d,p = np.linalg.eig(m)

# %%
p
# Out:
# matrix([[ 0.89442719, -0.4472136 ],
#         [-0.4472136 ,  0.89442719]])

# %%
y = np.linspace(-4,4,9)
temp = -4
x = np.empty((9, ))

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
while temp <= 4:
  x.fill(temp)
  temp = temp + 1
  plt.plot(x,y, color='cyan',lw=0.5)
  plt.plot(y,x, color='olive',lw=0.5)
  v = np.array([x,y])
  w = np.matmul(m,v)

plt.quiver(1,0,scale=8,color='blue')
plt.quiver(0,1,scale=8,color='brown')

# %%
v
# Out:
# array([[ 4.,  4.,  4.,  4.,  4.,  4.,  4.,  4.,  4.],
#        [-4., -3., -2., -1.,  0.,  1.,  2.,  3.,  4.]])

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(1, 1, 1)
# Move left y-axis and bottim x-axis to centre, passing through (0,0)
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
# Eliminate upper and right axes
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

# Show ticks in the left and lower axes only
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
while temp <= 4:
  x.fill(temp)
  temp = temp + 1
  plt.plot(x,y, color='cyan',lw=0.5)
  plt.plot(y,x, color='olive',lw=0.5)

plt.quiver(1,0,scale=8,color='blue')
plt.quiver(0,1,scale=8,color='brown')
