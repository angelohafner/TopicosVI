# %%
import numpy as np
import sympy as sym
A = sym.Matrix([[1, 2, -2],[ -1, -1,1],[  3, -3, -3]])
A
# Out:
# Matrix([
# [ 1,  2, -2],
# [-1, -1,  1],
# [ 3, -3, -3]])

# %%
b = sym.Matrix([[0],[5],[1]])
b
# Out:
# Matrix([
# [0],
# [5],
# [1]])

# %%
htk = A.inv() * b
h = htk[0]
t = htk[1]
k = htk[2]

# %%
x = 2 + 2*k
y = 2 - k
z = 2 + 3*k
x
# Out:
# -40/3

# %%
y
# Out:
# 29/3

# %%
z
# Out:
# -21

# %%
x = 2 + 1*h+2*t
y = -3 - 1*h-1*t
z = 1 + 3*h-3*t
x
# Out:
# -40/3

# %%
y
# Out:
# 29/3

# %%
z
# Out:
# -21
